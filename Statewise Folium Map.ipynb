# %%
import folium
from folium import plugins
import pandas as pd
import numpy as np
import geocoder
from folium.plugins import TimestampedGeoJson
from branca.element import Template, MacroElement

# %%
df0327 = pd.read_csv('Statewise-2020-03-27.csv')
df0327.drop(['Unnamed: 0'], axis=1, inplace = True)
df0327.rename(columns={"No of Positive cases (27-03-2020)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0327['Date'] = '2020-03-27'

df0329 = pd.read_csv('Statewise-2020-03-29.csv')
df0329.drop(['Unnamed: 0'], axis=1, inplace = True)
df0329.rename(columns={"No of Positive cases (2020-03-29)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0329['Date'] = '2020-03-29'

df0330 = pd.read_csv('Statewise-2020-03-30.csv')
df0330.drop(['Unnamed: 0'], axis=1, inplace = True)
df0330.rename(columns={"No of Positive cases (2020-03-30)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0330['Date'] = '2020-03-30'

df0401 = pd.read_csv('Statewise-2020-04-01.csv')
df0401.drop(['Unnamed: 0'], axis=1, inplace = True)
df0401.rename(columns={"No of Positive cases(2020-04-01)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0401['Date'] = '2020-04-01'

df0402 = pd.read_csv('Statewise-2020-04-02.csv')
df0402.drop(['Unnamed: 0'], axis=1, inplace = True)
df0402.rename(columns={"No of Positive cases(2020-04-02)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0402['Date'] = '2020-04-02'

df0403 = pd.read_csv('Statewise-2020-04-03.csv')
df0403.drop(['Unnamed: 0'], axis=1, inplace = True)
df0403.rename(columns={"No of Positive cases(2020-04-03)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0403['Date'] = '2020-04-03'

df0404 = pd.read_csv('Statewise-2020-04-04.csv')
df0404.drop(['Unnamed: 0'], axis=1, inplace = True)
df0404.rename(columns={"No of Positive cases(2020-04-04)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0404['Date'] = '2020-04-04'

df0405 = pd.read_csv('Statewise-2020-04-05.csv')
df0405.drop(['Unnamed: 0'], axis=1, inplace = True)
df0405.rename(columns={"No of Positive cases(2020-04-05)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0405['Date'] = '2020-04-05'

df0406 = pd.read_csv('Statewise-2020-04-06.csv')
df0406.drop(['Unnamed: 0'], axis=1, inplace = True)
df0406.rename(columns={"No of Positive cases(2020-04-06)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0406['Date'] = '2020-04-06'

df0407 = pd.read_csv('Statewise-2020-04-08.csv')
df0407.drop(['Unnamed: 0'], axis=1, inplace = True)
df0407.rename(columns={"No of Positive cases(2020-04-08)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0407['Date'] = '2020-04-07'

df0408 = pd.read_csv('Statewise-2020-04-08.csv')
df0408.drop(['Unnamed: 0'], axis=1, inplace = True)
df0408.rename(columns={"No of Positive cases(2020-04-08)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0408['Date'] = '2020-04-08'

df0409 = pd.read_csv('Statewise-2020-04-09.csv')
df0409.drop(['Unnamed: 0'], axis=1, inplace = True)
df0409.rename(columns={"No of Positive cases(2020-04-09)": "No of Positive cases", 'Lat': 'Latitude', 'Long': 'Longitude'}, inplace = True)
df0409['Date'] = '2020-04-09'

# %%
union = pd.concat([df0327,df0329,df0330,df0401,df0402,df0403,df0404,df0405,df0406,df0407,df0408,df0409], ignore_index=True)
union
# Out:
#                         State/UT  No of Positive cases   Latitude  Longitude  \
# 0    Andaman and Nicobar Islands                   1.0  10.218834  92.577133
# 1                 Andhra Pradesh                  12.0  15.924091  80.186381
# 2                          Bihar                   6.0  25.644085  85.906508
# 3                     Chandigarh                   7.0  30.719402  76.764655
# 4                   Chhattisgarh                   6.0  21.663736  81.840635
# ..                           ...                   ...        ...        ...
# 347                    Telengana                 442.0  17.329125  78.582223
# 348                      Tripura                   1.0  23.775082  91.702509
# 349                  Uttarakhand                  35.0  30.091994  79.321767
# 350                Uttar Pradesh                 410.0  27.130334  80.859666
# 351                  West Bengal                 116.0  22.996495  87.685588
#
#            Date
# 0    2020-03-27
# ...

# %%
#a66bff
#428bca
#0043fa
#fa5c00
union['Radius'] = ''
union['Color'] = ''
for e in range(0,len(union)):
    if 0<union['No of Positive cases'][e]<10:
        union['Radius'][e] = 5
        union['Color'][e] = '#ff9d00'
    if 10<=union['No of Positive cases'][e]<100:
        union['Radius'][e] = 8
        union['Color'][e] = '#a66bff'
    if 100<=union['No of Positive cases'][e]<300:
        union['Radius'][e] = 10
        union['Color'][e] = '#56e8ab'
    if 300<=union['No of Positive cases'][e]<500:
        union['Radius'][e] = 12
        union['Color'][e] = '#0043fa'
    if 500<=union['No of Positive cases'][e]:
        union['Radius'][e] = 14
        union['Color'][e] = '#ff0303'
    #if 100<=union['No of Positive cases'][e]:
     #   union['Radius'][e] = 9
      #  union['Color'][e] = '#ff0303'
# Out:
# C:\Users\Bala\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Bala\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Bala\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(union)
# Out:
#                         State/UT  No of Positive cases   Latitude  Longitude  \
# 0    Andaman and Nicobar Islands                   1.0  10.218834  92.577133
# 1                 Andhra Pradesh                  12.0  15.924091  80.186381
# 2                          Bihar                   6.0  25.644085  85.906508
# 3                     Chandigarh                   7.0  30.719402  76.764655
# 4                   Chhattisgarh                   6.0  21.663736  81.840635
# 5                          Delhi                  36.0  28.651718  77.221939
# 6                            Goa                   3.0  15.300454  74.085513
# 7                        Gujarat                  43.0  22.415408  72.031497
# 8                        Haryana                  30.0  29.000000  76.000000
# 9               Himachal Pradesh                   3.0  31.816760  77.349321
# 10             Jammu and Kashmir                  13.0  34.047656  76.797289
# ...

# %%
def create_geojson_features(df):
    features = []
    
    for _, row in df.iterrows():
        feature = {
            'type': 'Feature',
            'geometry': {
                'type':'Point', 
                'coordinates':[row['Longitude'],row['Latitude']]
            },
            'properties': {
                'time': row['Date'],
                'popup': {(row['Date'],row['State/UT']): row['No of Positive cases']}.__str__(),
                #'tooltip': tooltip,
                'style': {'color' : ''},
                'icon': 'circle',
                'iconstyle':{
                    'fillColor': row['Color'],
                    'fillOpacity': 0.8,
                    'stroke': 'true',
                    'radius': row['Radius']
                }
            }
        }
        features.append(feature)
    return features
start_geojson = create_geojson_features(union) 
start_geojson[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [92.57713290000001, 10.2188344]},
#  'properties': {'time': '2020-03-27',
#   'popup': "{('2020-03-27', 'Andaman and Nicobar Islands'): 1.0}",
#   'style': {'color': ''},
#   'icon': 'circle',
#   'iconstyle': {'fillColor': '#ff9d00',
#    'fillOpacity': 0.8,
#    'stroke': 'true',
#    'radius': 5}}}

# %%
m = folium.Map(location=[20.5937, 78.9629], zoom_start=4)
map = TimestampedGeoJson(start_geojson,
                  period = 'P1D',
                  duration = None,
                  transition_time = 1000,
                  min_speed = 0.001,
                  max_speed = 2,
                  auto_play = True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>
     
<div class='legend-title'>Prevalence of COVID-19 in Indian</div>
<div class='legend-title'>States from 27 Mar to 09 Apr</div>
<div class='legend-title'>(Click on map icons for more details)</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:#ff9d00;opacity:0.7;'></span>Less than 10 cases</li>
    <li><span style='background:#a66bff;opacity:0.7;'></span>Between 100 and 100 cases</li>
    <li><span style='background:#56e8ab;opacity:0.7;'></span>Between 100 to 300 cases</li>
    <li><span style='background:#0043fa;opacity:0.7;'></span>Between 300 to 500 cases</li>
    <li><span style='background:#ff0303;opacity:0.7;'></span>Greater 500 cases</li>

  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)

m.get_root().add_child(macro)

m.save('Prevalence_COVID-19_Indian_States.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
